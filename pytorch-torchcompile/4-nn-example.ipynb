# %%
import argparse
import json
import logging
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
import torchvision

from torchvision import datasets, transforms

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.set_float32_matmul_precision('high') #Uses TF32 when available

# %%
def _get_model():
    class Net(nn.Module):
        def __init__(self):
            super(Net, self).__init__()
            self.conv1 = nn.Conv2d(3, 6, 5)
            self.pool = nn.MaxPool2d(2, 2)
            self.conv2 = nn.Conv2d(6, 16, 5)
            self.fc1 = nn.Linear(16 * 5 * 5, 120)
            self.fc2 = nn.Linear(120, 84)
            self.fc3 = nn.Linear(84, 10)

        def forward(self, x):
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = x.view(-1, 16 * 5 * 5)
            x = F.relu(self.fc1(x))
            x = F.relu(self.fc2(x))
            x = self.fc3(x)
            return x
    return Net()

# %%
# Define data augmentation
def _get_transforms():
        transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
        return transform

# %%
def _get_dataloaders(batch_size):
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=_get_transforms())
    testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=_get_transforms())
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True)
    testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False)
    return trainloader, testloader

# %%
def test(model, test_loader, device):
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='mean').item()  # sum up batch loss
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print(f"Test set: Average loss: {test_loss}, Accuracy: {correct / len(test_loader.dataset)}\n")

# %%
import time
def train(model, batch_size, epochs):
    torch.manual_seed(0)
    lr = 0.01
    momentum=0.9
    train_loader, test_loader = _get_dataloaders(batch_size)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)

    for epoch in range(1, epochs + 1):
        start_time = time.time()
        for batch_idx, (data, target) in enumerate(train_loader, 1):
            data, target = data.to(device), target.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

        print(f"Train Epoch: {epoch} Epoch time: {time.time()-start_time:0.4f} Loss: {loss.item()}")
        test(model, test_loader, device)

# %%
# %%time
print("Train in eager mode on CIFAR-10")
model = _get_model().to(device)

train(model, batch_size=16, epochs=50)
# Out:
# Train in eager mode on CIFAR-10
# Files already downloaded and verified
# Files already downloaded and verified
# Train Epoch: 1 Epoch time: 18.4492 Loss: 1.5229963064193726
# Test set: Average loss: -0.11479381905794143, Accuracy: 0.3574
#
# Train Epoch: 2 Epoch time: 17.1039 Loss: 1.255014419555664
# Test set: Average loss: -0.12258006700873375, Accuracy: 0.4207
#
# Train Epoch: 3 Epoch time: 17.0540 Loss: 1.2103943824768066
# Test set: Average loss: -0.14219269587993622, Accuracy: 0.4306
#
# Train Epoch: 4 Epoch time: 17.1195 Loss: 1.6141940355300903
# Test set: Average loss: -0.1223116991698742, Accuracy: 0.4078
#
# Train Epoch: 5 Epoch time: 17.1593 Loss: 1.7167662382125854
# Test set: Average loss: -0.1371232023358345, Accuracy: 0.427
#
# Train Epoch: 6 Epoch time: 17.0450 Loss: 1.6442832946777344
# Test set: Average loss: -0.11765576581060887, Accuracy: 0.4195
#
# Train Epoch: 7 Epoch time: 17.2778 Loss: 1.1586203575134277
# Test set: Average loss: -0.12454334303736686, Accuracy: 0.4175
#
# Train Epoch: 8 Epoch time: 17.1429 Loss: 2.3159003257751465
# Test set: Average loss: -0.14869595084786416, Accuracy: 0.4542
#
# Train Epoch: 9 Epoch time: 17.0725 Loss: 1.63433039188385
# Test set: Average loss: -0.13449764105677606, Accuracy: 0.4416
#
# Train Epoch: 10 Epoch time: 17.1152 Loss: 0.9652916193008423
# Test set: Average loss: -0.14638293540477754, Accuracy: 0.4566
#
# Train Epoch: 11 Epoch time: 17.0312 Loss: 1.4068830013275146
# Test set: Average loss: -0.13832889040112495, Accuracy: 0.4099
#
# Train Epoch: 12 Epoch time: 17.1650 Loss: 1.6365031003952026
# Test set: Average loss: -0.1226353962123394, Accuracy: 0.427
#
# Train Epoch: 13 Epoch time: 17.1685 Loss: 1.2202277183532715
# Test set: Average loss: -0.16288705285787583, Accuracy: 0.4464
#
# Train Epoch: 14 Epoch time: 17.1915 Loss: 1.5230098962783813
# Test set: Average loss: -0.13382687171697616, Accuracy: 0.4507
#
# Train Epoch: 15 Epoch time: 17.1395 Loss: 1.6405322551727295
# Test set: Average loss: -0.11657781254947186, Accuracy: 0.418
#
# Train Epoch: 16 Epoch time: 17.1124 Loss: 1.435512661933899
# Test set: Average loss: -0.16411116136312484, Accuracy: 0.4536
#
# Train Epoch: 17 Epoch time: 17.0854 Loss: 1.3877995014190674
# Test set: Average loss: -0.13008506304621698, Accuracy: 0.4505
#
# Train Epoch: 18 Epoch time: 17.0801 Loss: 1.3181973695755005
# Test set: Average loss: -0.12966735948324204, Accuracy: 0.4444
#
# Train Epoch: 19 Epoch time: 17.1122 Loss: 1.3785901069641113
# Test set: Average loss: -0.16746452817320823, Accuracy: 0.4708
#
# Train Epoch: 20 Epoch time: 17.0873 Loss: 2.601522922515869
# Test set: Average loss: -0.1661388152360916, Accuracy: 0.455
#
# Train Epoch: 21 Epoch time: 17.1412 Loss: 1.387449026107788
# Test set: Average loss: -0.13323016968667506, Accuracy: 0.4078
#
# Train Epoch: 22 Epoch time: 17.0955 Loss: 0.9796938300132751
# Test set: Average loss: -0.12620635756850243, Accuracy: 0.4348
#
# Train Epoch: 23 Epoch time: 17.1453 Loss: 1.7141715288162231
# Test set: Average loss: -0.14345559119582177, Accuracy: 0.4657
#
# Train Epoch: 24 Epoch time: 17.1091 Loss: 1.4967659711837769
# Test set: Average loss: -0.12276398456394673, Accuracy: 0.4001
#
# Train Epoch: 25 Epoch time: 17.0620 Loss: 1.9967564344406128
# Test set: Average loss: -0.15137818831205369, Accuracy: 0.4591
#
# Train Epoch: 26 Epoch time: 17.0726 Loss: 1.2827167510986328
# Test set: Average loss: -0.14104595474600792, Accuracy: 0.4339
#
# Train Epoch: 27 Epoch time: 17.1130 Loss: 1.6564006805419922
# Test set: Average loss: -0.15558898612856864, Accuracy: 0.457
#
# Train Epoch: 28 Epoch time: 17.0406 Loss: 1.5395925045013428
# Test set: Average loss: -0.15071935195326805, Accuracy: 0.4298
#
# Train Epoch: 29 Epoch time: 17.0579 Loss: 2.140176773071289
# Test set: Average loss: -0.15748710156083107, Accuracy: 0.4236
#
# Train Epoch: 30 Epoch time: 17.0842 Loss: 1.7239465713500977
# Test set: Average loss: -0.14595504192709924, Accuracy: 0.4115
#
# Train Epoch: 31 Epoch time: 17.1039 Loss: 1.7769050598144531
# Test set: Average loss: -0.1290455259978771, Accuracy: 0.3998
#
# Train Epoch: 32 Epoch time: 17.1451 Loss: 1.662497639656067
# Test set: Average loss: -0.15571664265990257, Accuracy: 0.4357
#
# Train Epoch: 33 Epoch time: 17.1315 Loss: 1.3852906227111816
# Test set: Average loss: -0.1613605972111225, Accuracy: 0.4172
#
# Train Epoch: 34 Epoch time: 17.0798 Loss: 1.7368806600570679
# Test set: Average loss: -0.12401523492336274, Accuracy: 0.3968
#
# Train Epoch: 35 Epoch time: 17.1884 Loss: 1.463071584701538
# Test set: Average loss: -0.13350237726569175, Accuracy: 0.4211
#
# Train Epoch: 36 Epoch time: 17.0499 Loss: 1.222204327583313
# Test set: Average loss: -0.16071371198892592, Accuracy: 0.4386
#
# Train Epoch: 37 Epoch time: 17.0795 Loss: 1.59268319606781
# Test set: Average loss: -0.1448448682665825, Accuracy: 0.4142
#
# Train Epoch: 38 Epoch time: 17.0917 Loss: 1.8278884887695312
# Test set: Average loss: -0.13484705570042133, Accuracy: 0.4107
#
# Train Epoch: 39 Epoch time: 17.1323 Loss: 1.2747076749801636
# Test set: Average loss: -0.14489886118769646, Accuracy: 0.3949
#
# Train Epoch: 40 Epoch time: 17.1330 Loss: 1.6077611446380615
# Test set: Average loss: -0.14588061140179634, Accuracy: 0.4289
#
# Train Epoch: 41 Epoch time: 17.2133 Loss: 1.6331448554992676
# Test set: Average loss: -0.09960648607611657, Accuracy: 0.3682
#
# Train Epoch: 42 Epoch time: 17.1127 Loss: 1.2302451133728027
# Test set: Average loss: -0.14067820476591586, Accuracy: 0.4283
#
# Train Epoch: 43 Epoch time: 17.1447 Loss: 1.6978567838668823
# Test set: Average loss: -0.16264084021151065, Accuracy: 0.4108
#
# Train Epoch: 44 Epoch time: 17.0487 Loss: 1.2845810651779175
# Test set: Average loss: -0.13672254542708398, Accuracy: 0.444
#
# Train Epoch: 45 Epoch time: 17.1562 Loss: 1.1537847518920898
# Test set: Average loss: -0.14150477679371834, Accuracy: 0.4273
#
# Train Epoch: 46 Epoch time: 17.1326 Loss: 1.6309105157852173
# Test set: Average loss: -0.13888773401975632, Accuracy: 0.3973
#
# Train Epoch: 47 Epoch time: 17.1038 Loss: 1.398644208908081
# Test set: Average loss: -0.15300521407723428, Accuracy: 0.4311
#
# Train Epoch: 48 Epoch time: 17.1457 Loss: 1.8404948711395264
# Test set: Average loss: -0.1579221700131893, Accuracy: 0.4233
#
# Train Epoch: 49 Epoch time: 17.1388 Loss: 1.3540527820587158
# Test set: Average loss: -0.1460476183593273, Accuracy: 0.4527
#
# Train Epoch: 50 Epoch time: 17.1742 Loss: 1.765850305557251
# Test set: Average loss: -0.12122882234454155, Accuracy: 0.4141
#
# CPU times: user 16min 39s, sys: 6.23 s, total: 16min 45s
# Wall time: 16min 47s

# %%
# %%time
import torch._inductor.config
model = _get_model().to(device)
model = torch.compile(model, backend="inductor",
                      mode="max-autotune")

randinput = torch.randn(16,3,32,32).to(device)
randoutput = torch.randn(16,10).to(device)

print('Generating forward and backward graphs')
out = model(randinput)
nn.CrossEntropyLoss()(out, randoutput).backward()
# Out:
# Generating forward and backward graphs
# CPU times: user 1.01 s, sys: 12 ms, total: 1.02 s
# Wall time: 1.02 s

# %%
# %%time
print("Train in compiled mode on CIFAR-10")
model = _get_model().to(device)
train(model, batch_size=16, epochs=50)
# Out:
# Train in compiled mode on CIFAR-10
# Files already downloaded and verified
# Files already downloaded and verified
# Train Epoch: 1 Epoch time: 16.8979 Loss: 1.1281245946884155
# Test set: Average loss: -0.10141951135396958, Accuracy: 0.3753
#
# Train Epoch: 2 Epoch time: 16.8175 Loss: 1.5165073871612549
# Test set: Average loss: -0.11379602966904641, Accuracy: 0.4128
#
# Train Epoch: 3 Epoch time: 16.8435 Loss: 1.3197925090789795
# Test set: Average loss: -0.14007682649493217, Accuracy: 0.4195
#
# Train Epoch: 4 Epoch time: 17.1099 Loss: 1.7537651062011719
# Test set: Average loss: -0.12210166681408882, Accuracy: 0.444
#
# Train Epoch: 5 Epoch time: 16.9783 Loss: 1.5357666015625
# Test set: Average loss: -0.15047866759300232, Accuracy: 0.4326
#
# Train Epoch: 6 Epoch time: 16.7821 Loss: 1.6223543882369995
# Test set: Average loss: -0.143238749986887, Accuracy: 0.4263
#
# Train Epoch: 7 Epoch time: 16.8694 Loss: 1.7723138332366943
# Test set: Average loss: -0.12494028667807579, Accuracy: 0.4065
#
# Train Epoch: 8 Epoch time: 16.8882 Loss: 1.8077551126480103
# Test set: Average loss: -0.1637685509085655, Accuracy: 0.4561
#
# Train Epoch: 9 Epoch time: 16.8302 Loss: 1.4599609375
# Test set: Average loss: -0.1516111361026764, Accuracy: 0.4451
#
# Train Epoch: 10 Epoch time: 16.8638 Loss: 1.1293983459472656
# Test set: Average loss: -0.16525690048933028, Accuracy: 0.4697
#
# Train Epoch: 11 Epoch time: 16.8586 Loss: 0.9164922833442688
# Test set: Average loss: -0.15961521873474122, Accuracy: 0.4466
#
# Train Epoch: 12 Epoch time: 16.7826 Loss: 2.045623779296875
# Test set: Average loss: -0.10865869052410125, Accuracy: 0.4195
#
# Train Epoch: 13 Epoch time: 16.8195 Loss: 1.2999463081359863
# Test set: Average loss: -0.17005301181674004, Accuracy: 0.4713
#
# Train Epoch: 14 Epoch time: 16.8872 Loss: 1.5532177686691284
# Test set: Average loss: -0.17997907676696778, Accuracy: 0.4673
#
# Train Epoch: 15 Epoch time: 16.7638 Loss: 1.6674301624298096
# Test set: Average loss: -0.13775004784464837, Accuracy: 0.4458
#
# Train Epoch: 16 Epoch time: 16.8711 Loss: 1.7492315769195557
# Test set: Average loss: -0.17715689504146576, Accuracy: 0.4702
#
# Train Epoch: 17 Epoch time: 16.8545 Loss: 1.4167125225067139
# Test set: Average loss: -0.13974063433408737, Accuracy: 0.4377
#
# Train Epoch: 18 Epoch time: 16.8798 Loss: 1.9101390838623047
# Test set: Average loss: -0.1401785773575306, Accuracy: 0.4311
#
# Train Epoch: 19 Epoch time: 16.8081 Loss: 1.99967622756958
# Test set: Average loss: -0.1516777255654335, Accuracy: 0.4445
#
# Train Epoch: 20 Epoch time: 16.7739 Loss: 2.2190351486206055
# Test set: Average loss: -0.1643785246193409, Accuracy: 0.4545
#
# Train Epoch: 21 Epoch time: 17.1348 Loss: 1.7950257062911987
# Test set: Average loss: -0.17522918835878373, Accuracy: 0.4574
#
# Train Epoch: 22 Epoch time: 16.9389 Loss: 1.5520081520080566
# Test set: Average loss: -0.15325675513744355, Accuracy: 0.4569
#
# Train Epoch: 23 Epoch time: 16.8428 Loss: 1.663689374923706
# Test set: Average loss: -0.17498237799406052, Accuracy: 0.4514
#
# Train Epoch: 24 Epoch time: 16.8972 Loss: 2.0213215351104736
# Test set: Average loss: -0.12325149633288383, Accuracy: 0.4142
#
# Train Epoch: 25 Epoch time: 16.8106 Loss: 2.0409820079803467
# Test set: Average loss: -0.12809701528549194, Accuracy: 0.4128
#
# Train Epoch: 26 Epoch time: 16.7998 Loss: 1.821916103363037
# Test set: Average loss: -0.13387244796156883, Accuracy: 0.4204
#
# Train Epoch: 27 Epoch time: 16.8039 Loss: 1.3090702295303345
# Test set: Average loss: -0.15662841452360154, Accuracy: 0.4604
#
# Train Epoch: 28 Epoch time: 16.9014 Loss: 1.2767252922058105
# Test set: Average loss: -0.17367174760699272, Accuracy: 0.4426
#
# Train Epoch: 29 Epoch time: 16.7807 Loss: 1.9910852909088135
# Test set: Average loss: -0.138916358846426, Accuracy: 0.3752
#
# Train Epoch: 30 Epoch time: 16.7389 Loss: 1.2423659563064575
# Test set: Average loss: -0.14196027348041534, Accuracy: 0.4424
#
# Train Epoch: 31 Epoch time: 16.8019 Loss: 1.6152451038360596
# Test set: Average loss: -0.15072507199048996, Accuracy: 0.4381
#
# Train Epoch: 32 Epoch time: 16.8864 Loss: 1.6289972066879272
# Test set: Average loss: -0.11902655415534973, Accuracy: 0.4208
#
# Train Epoch: 33 Epoch time: 16.7390 Loss: 1.3837391138076782
# Test set: Average loss: -0.15387935359477997, Accuracy: 0.4218
#
# Train Epoch: 34 Epoch time: 16.7903 Loss: 1.516900658607483
# Test set: Average loss: -0.1460586778521538, Accuracy: 0.4429
#
# Train Epoch: 35 Epoch time: 16.7645 Loss: 1.8662484884262085
# Test set: Average loss: -0.1500231746673584, Accuracy: 0.4308
#
# Train Epoch: 36 Epoch time: 16.7263 Loss: 1.570525884628296
# Test set: Average loss: -0.17256923723816872, Accuracy: 0.4522
#
# Train Epoch: 37 Epoch time: 16.7440 Loss: 1.7509129047393799
# Test set: Average loss: -0.1331960899591446, Accuracy: 0.4025
#
# Train Epoch: 38 Epoch time: 16.6792 Loss: 1.6465048789978027
# Test set: Average loss: -0.17207880718111992, Accuracy: 0.463
#
# Train Epoch: 39 Epoch time: 16.7337 Loss: 1.4757962226867676
# Test set: Average loss: -0.1252164648413658, Accuracy: 0.435
#
# Train Epoch: 40 Epoch time: 16.7789 Loss: 2.02087140083313
# Test set: Average loss: -0.12817251023054124, Accuracy: 0.4488
#
# Train Epoch: 41 Epoch time: 16.7497 Loss: 1.4727895259857178
# Test set: Average loss: -0.1616751208484173, Accuracy: 0.4522
#
# Train Epoch: 42 Epoch time: 16.8264 Loss: 1.214515209197998
# Test set: Average loss: -0.09364713019430637, Accuracy: 0.3973
#
# Train Epoch: 43 Epoch time: 16.6972 Loss: 1.874068021774292
# Test set: Average loss: -0.17249812202453613, Accuracy: 0.4564
#
# Train Epoch: 44 Epoch time: 16.9201 Loss: 1.4941129684448242
# Test set: Average loss: -0.14445521401762962, Accuracy: 0.4388
#
# Train Epoch: 45 Epoch time: 16.7735 Loss: 1.3479551076889038
# Test set: Average loss: -0.1443574243813753, Accuracy: 0.4296
#
# Train Epoch: 46 Epoch time: 16.7243 Loss: 1.9566048383712769
# Test set: Average loss: -0.1257232101917267, Accuracy: 0.3808
#
# Train Epoch: 47 Epoch time: 16.7802 Loss: 1.851891279220581
# Test set: Average loss: -0.09098090907037258, Accuracy: 0.3395
#
# Train Epoch: 48 Epoch time: 16.7901 Loss: 1.5767955780029297
# Test set: Average loss: -0.1268459755897522, Accuracy: 0.4005
#
# Train Epoch: 49 Epoch time: 16.7760 Loss: 1.6413697004318237
# Test set: Average loss: -0.13277969150543212, Accuracy: 0.4223
#
# Train Epoch: 50 Epoch time: 16.6827 Loss: 1.7723995447158813
# Test set: Average loss: -0.1290963588565588, Accuracy: 0.3967
#
# CPU times: user 16min 20s, sys: 5.69 s, total: 16min 25s
# Wall time: 16min 27s

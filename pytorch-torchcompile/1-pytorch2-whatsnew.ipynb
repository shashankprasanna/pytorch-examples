# %%
import torch
import os
import torch._dynamo
os.getenv('TORCH_COMPILE_DEBUG')
# Out:
# '1'

# %%
class MLP (nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear (1024, 1024)
        self.fc2 = nn.Linear (1024, 1024)
        
    def forward(self, x):
        x = self. fc1(X) . relu() ** 2
        return self.fc2(x).relu() ** 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class MLP (nn.Module):
#       2     def __init__(self):
#       3         super().__init__()
#
# NameError: name 'nn' is not defined

# %%
import torch
def fn(x, y):
    a = torch.sin(x).cuda()
    b = torch.sin(y).cuda()
    return a + b
new_fn = torch.compile(fn, backend="inductor")
input_tensor = torch.randn(10000).to(device="cuda:0")
a = new_fn(input_tensor, input_tensor)

# %%
import os
os.environ['TORCH_COMPILE_DEBUG'] = '1'
os.getenv('TORCH_COMPILE_DEBUG')
# Out:
# '1'

# %%
torch._dynamo.list_backends()
# Out:
# ['aot_ts_nvfuser',
#  'cudagraphs',
#  'inductor',
#  'ipex',
#  'nvprims_nvfuser',
#  'onnxrt',
#  'tvm']

# %%
import os
import torch
from transformers import BertTokenizer, BertModel

os.environ['TORCH_COMPILE_DEBUG'] = '1'

# Copy pasted from here https://huggingface.co/bert-base-uncased
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased").to(device="cuda:0")
model = torch.compile(model) # This is the only line of code that we changed
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt').to(device="cuda:0")
output = model(**encoded_input)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [2023-03-08 21:28:24,015] torch._dynamo.eval_frame: [DEBUG] skipping __init__ /opt/conda/lib/python3.10/contextlib.py
# [2023-03-08 21:28:24,016] torch._dynamo.eval_frame: [DEBUG] skipping __enter__ /opt/conda/lib/python3.10/contextlib.py
# [2023-03-08 21:28:24,016] torch._dynamo.eval_frame: [DEBUG] skipping __init__ /opt/conda/lib/python3.10/contextlib.py
# [2023-03-08 21:28:24,017] torch._dynamo.eval_frame: [DEBUG] skipping __enter__ /opt/conda/lib/python3.10/contextlib.py
# [2023-03-08 21:28:24,018] torch._dynamo.eval_frame: [DEBUG] skipping enable_dynamic /opt/conda/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py
# [2023-03-08 21:28:24,018] torch._dynamo.eval_frame: [DEBUG] skipping _call_impl /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py
# [2023-03-08 21:28:24,116] torch._dynamo.symbolic_convert: [INFO] Step 1: torchdynamo start tracing forward
# [2023-03-08 21:28:24,117] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:953
# [2023-03-08 21:28:24,118] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST output_attentions []
# [2023-03-08 21:28:24,119] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,119] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,120] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 12 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,121] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,121] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR config [NNModuleVariable()]
# [2023-03-08 21:28:24,123] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR output_attentions [HFPretrainedConfigVariable()]
# [2023-03-08 21:28:24,124] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST output_attentions [ConstantVariable(bool)]
# [2023-03-08 21:28:24,125] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:955
# [2023-03-08 21:28:24,126] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST output_hidden_states []
# [2023-03-08 21:28:24,126] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,127] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,127] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 32 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,128] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,129] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR config [NNModuleVariable()]
# [2023-03-08 21:28:24,130] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR output_hidden_states [HFPretrainedConfigVariable()]
# [2023-03-08 21:28:24,130] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:954
# [2023-03-08 21:28:24,131] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST output_hidden_states [ConstantVariable(bool)]
# [2023-03-08 21:28:24,131] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:957
# [2023-03-08 21:28:24,132] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST return_dict []
# [2023-03-08 21:28:24,133] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,133] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,134] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 52 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,134] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,135] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR config [NNModuleVariable()]
# [2023-03-08 21:28:24,136] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR use_return_dict [HFPretrainedConfigVariable()]
# [2023-03-08 21:28:24,137] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST return_dict [ConstantVariable(bool)]
# [2023-03-08 21:28:24,137] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:959
# [2023-03-08 21:28:24,138] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,138] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR config [NNModuleVariable()]
# [2023-03-08 21:28:24,139] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR is_decoder [HFPretrainedConfigVariable()]
# [2023-03-08 21:28:24,140] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 90 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,141] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:962
# [2023-03-08 21:28:24,145] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST False []
# [2023-03-08 21:28:24,145] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST use_cache [ConstantVariable(bool)]
# [2023-03-08 21:28:24,146] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:964
# [2023-03-08 21:28:24,146] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_ids []
# [2023-03-08 21:28:24,147] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TensorVariable()]
# [2023-03-08 21:28:24,147] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [TensorVariable(), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,148] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 118 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,149] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST inputs_embeds []
# [2023-03-08 21:28:24,150] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,151] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,151] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 118 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,152] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:966
# [2023-03-08 21:28:24,152] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_ids []
# [2023-03-08 21:28:24,153] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TensorVariable()]
# [2023-03-08 21:28:24,153] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [TensorVariable(), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,154] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 136 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,155] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:967
# [2023-03-08 21:28:24,155] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_ids []
# [2023-03-08 21:28:24,156] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR size [TensorVariable()]
# [2023-03-08 21:28:24,157] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 0 [GetAttrVariable(TensorVariable(), size)]
# [2023-03-08 21:28:24,157] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST input_shape [SizeVariable()]
# [2023-03-08 21:28:24,158] torch._dynamo.symbolic_convert: [DEBUG] TRACE JUMP_FORWARD 170 []
# [2023-03-08 21:28:24,158] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:973
# [2023-03-08 21:28:24,159] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_shape []
# [2023-03-08 21:28:24,160] torch._dynamo.symbolic_convert: [DEBUG] TRACE UNPACK_SEQUENCE 2 [SizeVariable()]
# [2023-03-08 21:28:24,160] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST batch_size [ConstantVariable(int), ConstantVariable(int)]
# [2023-03-08 21:28:24,161] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST seq_length [ConstantVariable(int)]
# [2023-03-08 21:28:24,161] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:974
# [2023-03-08 21:28:24,162] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_ids []
# [2023-03-08 21:28:24,162] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TensorVariable()]
# [2023-03-08 21:28:24,163] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [TensorVariable(), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,164] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 192 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,164] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_ids []
# [2023-03-08 21:28:24,165] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR device [TensorVariable()]
# [2023-03-08 21:28:24,166] torch._dynamo.symbolic_convert: [DEBUG] TRACE JUMP_FORWARD 196 [TorchVariable(cuda:0)]
# [2023-03-08 21:28:24,166] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST device [TorchVariable(cuda:0)]
# [2023-03-08 21:28:24,167] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:977
# [2023-03-08 21:28:24,167] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST past_key_values []
# [2023-03-08 21:28:24,168] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,168] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 1 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,169] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 224 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,170] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST 0 []
# [2023-03-08 21:28:24,174] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST past_key_values_length [ConstantVariable(int)]
# [2023-03-08 21:28:24,174] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:979
# [2023-03-08 21:28:24,175] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST attention_mask []
# [2023-03-08 21:28:24,175] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TensorVariable()]
# [2023-03-08 21:28:24,176] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 0 [TensorVariable(), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,176] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 258 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,177] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:982
# [2023-03-08 21:28:24,178] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST token_type_ids []
# [2023-03-08 21:28:24,179] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TensorVariable()]
# [2023-03-08 21:28:24,179] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 0 [TensorVariable(), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,180] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 338 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,180] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:992
# [2023-03-08 21:28:24,181] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,182] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR get_extended_attention_mask [NNModuleVariable()]
# [2023-03-08 21:28:24,183] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST attention_mask [UserMethodVariable(<function ModuleUtilsMixin.get_extended_attention_mask at 0x7f999eb001f0>, NNModuleVariable())]
# [2023-03-08 21:28:24,183] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_shape [UserMethodVariable(<function ModuleUtilsMixin.get_extended_attention_mask at 0x7f999eb001f0>, NNModuleVariable()), TensorVariable()]
# [2023-03-08 21:28:24,184] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 2 [UserMethodVariable(<function ModuleUtilsMixin.get_extended_attention_mask at 0x7f999eb001f0>, NNModuleVariable()), TensorVariable(), SizeVariable()]
# [2023-03-08 21:28:24,185] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object get_extended_attention_mask at 0x7f999f1ac710, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 789>
#  804           0 LOAD_FAST                4 (dtype)
#               2 LOAD_CONST               1 (None)
#               4 IS_OP                    0
#               6 POP_JUMP_IF_FALSE        7 (to 14)
#
# 805           8 LOAD_FAST                0 (self)
#              10 LOAD_ATTR                0 (dtype)
#              12 STORE_FAST               4 (dtype)
#
# 807     >>   14 LOAD_FAST                1 (attention_mask)
#              16 LOAD_METHOD              1 (dim)
#              18 CALL_METHOD              0
#              20 LOAD_CONST               2 (2)
#              22 COMPARE_OP               2 (==)
#              24 POP_JUMP_IF_FALSE       17 (to 34)
#              26 LOAD_FAST                0 (self)
#              28 LOAD_ATTR                2 (config)
#              30 LOAD_ATTR                3 (is_decoder)
#              32 POP_JUMP_IF_TRUE        27 (to 54)
#
# 809     >>   34 LOAD_FAST                3 (device)
#              36 LOAD_CONST               1 (None)
#              38 IS_OP                    1
#              40 POP_JUMP_IF_FALSE       27 (to 54)
#
# 810          42 LOAD_GLOBAL              4 (warnings)
#              44 LOAD_METHOD              5 (warn)
#
# 811          46 LOAD_CONST               3 ('The `device` argument is deprecated and will be removed in v5 of Transformers.')
#              48 LOAD_GLOBAL              6 (FutureWarning)
#
# 810          50 CALL_METHOD              2
#              52 POP_TOP
#
# 815     >>   54 LOAD_FAST                1 (attention_mask)
#              56 LOAD_METHOD              1 (dim)
#              58 CALL_METHOD              0
#              60 LOAD_CONST               4 (3)
#              62 COMPARE_OP               2 (==)
#              64 POP_JUMP_IF_FALSE       48 (to 96)
#
# 816          66 LOAD_FAST                1 (attention_mask)
#              68 LOAD_CONST               1 (None)
#              70 LOAD_CONST               1 (None)
#              72 BUILD_SLICE              2
#              74 LOAD_CONST               1 (None)
#              76 LOAD_CONST               1 (None)
#              78 LOAD_CONST               1 (None)
#              80 BUILD_SLICE              2
#              82 LOAD_CONST               1 (None)
#              84 LOAD_CONST               1 (None)
#              86 BUILD_SLICE              2
#              88 BUILD_TUPLE              4
#              90 BINARY_SUBSCR
#              92 STORE_FAST               5 (extended_attention_mask)
#              94 JUMP_FORWARD            43 (to 182)
#
# 817     >>   96 LOAD_FAST                1 (attention_mask)
#              98 LOAD_METHOD              1 (dim)
#             100 CALL_METHOD              0
#             102 LOAD_CONST               2 (2)
#             104 COMPARE_OP               2 (==)
#             106 POP_JUMP_IF_FALSE       79 (to 158)
#
# 821         108 LOAD_FAST                0 (self)
#             110 LOAD_ATTR                2 (config)
#             112 LOAD_ATTR                3 (is_decoder)
#             114 POP_JUMP_IF_FALSE       66 (to 132)
#
# 822         116 LOAD_GLOBAL              7 (ModuleUtilsMixin)
#             118 LOAD_METHOD              8 (create_extended_attention_mask_for_decoder)
#
# 823         120 LOAD_FAST                2 (input_shape)
#             122 LOAD_FAST                1 (attention_mask)
#             124 LOAD_FAST                3 (device)
#
# 822         126 CALL_METHOD              3
#             128 STORE_FAST               5 (extended_attention_mask)
#             130 JUMP_FORWARD            25 (to 182)
#
# 826     >>  132 LOAD_FAST                1 (attention_mask)
#             134 LOAD_CONST               1 (None)
#             136 LOAD_CONST               1 (None)
#             138 BUILD_SLICE              2
#             140 LOAD_CONST               1 (None)
#             142 LOAD_CONST               1 (None)
#             144 LOAD_CONST               1 (None)
#             146 LOAD_CONST               1 (None)
#             148 BUILD_SLICE              2
#             150 BUILD_TUPLE              4
#             152 BINARY_SUBSCR
#             154 STORE_FAST               5 (extended_attention_mask)
#             156 JUMP_FORWARD            12 (to 182)
#
# 828     >>  158 LOAD_GLOBAL              9 (ValueError)
#
# 829         160 LOAD_CONST               5 ('Wrong shape for input_ids (shape ')
#             162 LOAD_FAST                2 (input_shape)
#             164 FORMAT_VALUE             0
#             166 LOAD_CONST               6 (') or attention_mask (shape ')
#             168 LOAD_FAST                1 (attention_mask)
#             170 LOAD_ATTR               10 (shape)
#             172 FORMAT_VALUE             0
#             174 LOAD_CONST               7 (')')
#             176 BUILD_STRING             5
#
# 828         178 CALL_FUNCTION            1
#             180 RAISE_VARARGS            1
#
# 837     >>  182 LOAD_FAST                5 (extended_attention_mask)
#             184 LOAD_ATTR               11 (to)
#             186 LOAD_FAST                4 (dtype)
#             188 LOAD_CONST               8 (('dtype',))
#             190 CALL_FUNCTION_KW         1
#             192 STORE_FAST               5 (extended_attention_mask)
#
# 838         194 LOAD_CONST               9 (1.0)
#             196 LOAD_FAST                5 (extended_attention_mask)
#             198 BINARY_SUBTRACT
#             200 LOAD_GLOBAL             12 (torch)
#             202 LOAD_METHOD             13 (finfo)
#             204 LOAD_FAST                4 (dtype)
#             206 CALL_METHOD              1
#             208 LOAD_ATTR               14 (min)
#             210 BINARY_MULTIPLY
#             212 STORE_FAST               5 (extended_attention_mask)
#
# 839         214 LOAD_FAST                5 (extended_attention_mask)
#             216 RETURN_VALUE
#
#
# [2023-03-08 21:28:24,188] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:804
# [2023-03-08 21:28:24,189] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST dtype []
# [2023-03-08 21:28:24,189] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,190] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 0 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,191] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 14 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,191] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:805
# [2023-03-08 21:28:24,192] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,192] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR dtype [NNModuleVariable()]
# [2023-03-08 21:28:24,193] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object dtype at 0x7f999f1ac500, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 730>
#  735           0 LOAD_GLOBAL              0 (get_parameter_dtype)
#               2 LOAD_FAST                0 (self)
#               4 CALL_FUNCTION            1
#               6 RETURN_VALUE
#
#
# [2023-03-08 21:28:24,195] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:735
# [2023-03-08 21:28:24,195] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL get_parameter_dtype []
# [2023-03-08 21:28:24,196] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self [UserFunctionVariable()]
# [2023-03-08 21:28:24,197] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 1 [UserFunctionVariable(), NNModuleVariable()]
# [2023-03-08 21:28:24,198] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object get_parameter_dtype at 0x7f999f16cea0, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 181>
#  185           0 LOAD_CONST               1 (None)
#               2 STORE_FAST               1 (last_dtype)
#
# 186           4 LOAD_FAST                0 (parameter)
#               6 LOAD_METHOD              0 (parameters)
#               8 CALL_METHOD              0
#              10 GET_ITER
#         >>   12 FOR_ITER                52 (to 118)
#              14 STORE_FAST               2 (t)
#
# 187          16 LOAD_FAST                2 (t)
#              18 LOAD_ATTR                1 (dtype)
#              20 STORE_FAST               1 (last_dtype)
#
# 188          22 LOAD_FAST                2 (t)
#              24 LOAD_METHOD              2 (is_floating_point)
#              26 CALL_METHOD              0
#              28 POP_JUMP_IF_FALSE       58 (to 116)
#
# 192          30 LOAD_GLOBAL              3 (is_torch_tpu_available)
#              32 CALL_FUNCTION            0
#              34 POP_JUMP_IF_FALSE       53 (to 106)
#
# 193          36 LOAD_GLOBAL              4 (XLA_USE_BF16)
#              38 LOAD_GLOBAL              5 (ENV_VARS_TRUE_VALUES)
#              40 CONTAINS_OP              0
#              42 POP_JUMP_IF_FALSE       27 (to 54)
#
# 194          44 LOAD_GLOBAL              6 (torch)
#              46 LOAD_ATTR                7 (bfloat16)
#              48 ROT_TWO
#              50 POP_TOP
#              52 RETURN_VALUE
#
# 195     >>   54 LOAD_GLOBAL              8 (XLA_DOWNCAST_BF16)
#              56 LOAD_GLOBAL              5 (ENV_VARS_TRUE_VALUES)
#              58 CONTAINS_OP              0
#              60 POP_JUMP_IF_FALSE       53 (to 106)
#
# 196          62 LOAD_FAST                2 (t)
#              64 LOAD_ATTR                1 (dtype)
#              66 LOAD_GLOBAL              6 (torch)
#              68 LOAD_ATTR                9 (float)
#              70 COMPARE_OP               2 (==)
#              72 POP_JUMP_IF_FALSE       42 (to 84)
#
# 197          74 LOAD_GLOBAL              6 (torch)
#              76 LOAD_ATTR                7 (bfloat16)
#              78 ROT_TWO
#              80 POP_TOP
#              82 RETURN_VALUE
#
# 198     >>   84 LOAD_FAST                2 (t)
#              86 LOAD_ATTR                1 (dtype)
#              88 LOAD_GLOBAL              6 (torch)
#              90 LOAD_ATTR               10 (double)
#              92 COMPARE_OP               2 (==)
#              94 POP_JUMP_IF_FALSE       53 (to 106)
#
# 199          96 LOAD_GLOBAL              6 (torch)
#              98 LOAD_ATTR               11 (float32)
#             100 ROT_TWO
#             102 POP_TOP
#             104 RETURN_VALUE
#
# 200     >>  106 LOAD_FAST                2 (t)
#             108 LOAD_ATTR                1 (dtype)
#             110 ROT_TWO
#             112 POP_TOP
#             114 RETURN_VALUE
#
# 188     >>  116 JUMP_ABSOLUTE            6 (to 12)
#
# 202     >>  118 LOAD_FAST                1 (last_dtype)
#             120 LOAD_CONST               1 (None)
#             122 IS_OP                    1
#             124 POP_JUMP_IF_FALSE       65 (to 130)
#
# 204         126 LOAD_FAST                1 (last_dtype)
#             128 RETURN_VALUE
#
# 208     >>  130 LOAD_CONST               2 ('module')
#             132 LOAD_GLOBAL             12 (nn)
#             134 LOAD_ATTR               13 (Module)
#             136 LOAD_CONST               3 ('return')
#             138 LOAD_GLOBAL             14 (List)
#             140 LOAD_GLOBAL             15 (Tuple)
#             142 LOAD_GLOBAL             16 (str)
#             144 LOAD_GLOBAL             17 (Tensor)
#             146 BUILD_TUPLE              2
#             148 BINARY_SUBSCR
#             150 BINARY_SUBSCR
#             152 BUILD_TUPLE              4
#             154 LOAD_CONST               4 (<code object find_tensor_attributes at 0x7f999f16cdf0, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 208>)
#             156 LOAD_CONST               5 ('get_parameter_dtype.<locals>.find_tensor_attributes')
#             158 MAKE_FUNCTION            4 (annotations)
#             160 STORE_FAST               3 (find_tensor_attributes)
#
# 212         162 LOAD_FAST                0 (parameter)
#             164 LOAD_ATTR               18 (_named_members)
#             166 LOAD_FAST                3 (find_tensor_attributes)
#             168 LOAD_CONST               6 (('get_members_fn',))
#             170 CALL_FUNCTION_KW         1
#             172 STORE_FAST               4 (gen)
#
# 213         174 LOAD_CONST               1 (None)
#             176 STORE_FAST               5 (last_tuple)
#
# 214         178 LOAD_FAST                4 (gen)
#             180 GET_ITER
#         >>  182 FOR_ITER                17 (to 218)
#             184 STORE_FAST               6 (tuple)
#
# 215         186 LOAD_FAST                6 (tuple)
#             188 STORE_FAST               5 (last_tuple)
#
# 216         190 LOAD_FAST                6 (tuple)
#             192 LOAD_CONST               7 (1)
#             194 BINARY_SUBSCR
#             196 LOAD_METHOD              2 (is_floating_point)
#             198 CALL_METHOD              0
#             200 POP_JUMP_IF_FALSE      108 (to 216)
#
# 217         202 LOAD_FAST                6 (tuple)
#             204 LOAD_CONST               7 (1)
#             206 BINARY_SUBSCR
#             208 LOAD_ATTR                1 (dtype)
#             210 ROT_TWO
#             212 POP_TOP
#             214 RETURN_VALUE
#
# 216     >>  216 JUMP_ABSOLUTE           91 (to 182)
#
# 220     >>  218 LOAD_FAST                5 (last_tuple)
#             220 LOAD_CONST               7 (1)
#             222 BINARY_SUBSCR
#             224 LOAD_ATTR                1 (dtype)
#             226 RETURN_VALUE
#
#
# [2023-03-08 21:28:24,199] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:185
# [2023-03-08 21:28:24,200] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None []
# [2023-03-08 21:28:24,200] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST last_dtype [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,201] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:186
# [2023-03-08 21:28:24,201] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST parameter []
# [2023-03-08 21:28:24,202] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR parameters [NNModuleVariable()]
# [2023-03-08 21:28:24,203] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 0 [UserMethodVariable(<function Module.parameters at 0x7f99a56bdf30>, NNModuleVariable())]
# [2023-03-08 21:28:24,423] torch._dynamo.symbolic_convert: [DEBUG] TRACE GET_ITER None [ListIteratorVariable()]
# [2023-03-08 21:28:24,428] torch._dynamo.symbolic_convert: [DEBUG] TRACE FOR_ITER 118 [ListIteratorVariable()]
# [2023-03-08 21:28:24,429] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST t [ListIteratorVariable(), TensorVariable()]
# [2023-03-08 21:28:24,430] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:187
# [2023-03-08 21:28:24,430] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST t [ListIteratorVariable()]
# [2023-03-08 21:28:24,431] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR dtype [ListIteratorVariable(), TensorVariable()]
# [2023-03-08 21:28:24,432] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST last_dtype [ListIteratorVariable(), TorchVariable(torch.float32)]
# [2023-03-08 21:28:24,432] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:188
# [2023-03-08 21:28:24,433] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST t [ListIteratorVariable()]
# [2023-03-08 21:28:24,433] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR is_floating_point [ListIteratorVariable(), TensorVariable()]
# [2023-03-08 21:28:24,434] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 0 [ListIteratorVariable(), GetAttrVariable(TensorVariable(), is_floating_point)]
# [2023-03-08 21:28:24,435] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 116 [ListIteratorVariable(), ConstantVariable(bool)]
# [2023-03-08 21:28:24,435] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:192
# [2023-03-08 21:28:24,436] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL is_torch_tpu_available [ListIteratorVariable()]
# [2023-03-08 21:28:24,437] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 0 [ListIteratorVariable(), UserDefinedObjectVariable(_lru_cache_wrapper)]
# [2023-03-08 21:28:24,437] torch._dynamo.symbolic_convert: [DEBUG] FAILED INLINING <code object get_parameter_dtype at 0x7f999f16cea0, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 181>
# [2023-03-08 21:28:24,441] torch._dynamo.output_graph: [DEBUG] restore_graphstate: removed 199 nodes
# [2023-03-08 21:28:24,441] torch._dynamo.symbolic_convert: [DEBUG] FAILED INLINING <code object dtype at 0x7f999f1ac500, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 730>
# [2023-03-08 21:28:24,442] torch._dynamo.output_graph: [DEBUG] restore_graphstate: removed 0 nodes
# [2023-03-08 21:28:24,443] torch._dynamo.symbolic_convert: [DEBUG] FAILED INLINING <code object get_extended_attention_mask at 0x7f999f1ac710, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 789>
# [2023-03-08 21:28:24,443] torch._dynamo.output_graph: [DEBUG] restore_graphstate: removed 0 nodes
# [2023-03-08 21:28:24,444] torch._dynamo.symbolic_convert: [DEBUG] break_graph_if_unsupported triggered compile
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 349, in wrapper
#     return inner_fn(self, inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1014, in CALL_FUNCTION
#     self.call_function(fn, args, {})
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 517, in call_function
#     self.push(fn.call_function(self, args, kwargs))
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 292, in call_function
#     return super().call_function(tx, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 260, in call_function
#     return super().call_function(tx, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 93, in call_function
#     return tx.inline_user_function_return(
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 553, in inline_user_function_return
#     result = InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1955, in inline_call
#     return cls.inline_call_(parent, func, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 2011, in inline_call_
#     tracer.run()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 619, in run
#     and self.step()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 583, in step
#     getattr(self, inst.opname)(inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1087, in LOAD_ATTR
#     result = BuiltinVariable(getattr).call_function(
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/builtin.py", line 561, in call_function
#     result = handler(tx, *args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/builtin.py", line 972, in call_getattr
#     return obj.var_getattr(tx, name).add_options(options)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/nn_module.py", line 166, in var_getattr
#     ).call_function(tx, [(self)], {})
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 260, in call_function
#     return super().call_function(tx, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 93, in call_function
#     return tx.inline_user_function_return(
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 553, in inline_user_function_return
#     result = InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1955, in inline_call
#     return cls.inline_call_(parent, func, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 2011, in inline_call_
#     tracer.run()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 619, in run
#     and self.step()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 583, in step
#     getattr(self, inst.opname)(inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 349, in wrapper
#     return inner_fn(self, inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1014, in CALL_FUNCTION
#     self.call_function(fn, args, {})
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 517, in call_function
#     self.push(fn.call_function(self, args, kwargs))
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 260, in call_function
#     return super().call_function(tx, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 93, in call_function
#     return tx.inline_user_function_return(
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 553, in inline_user_function_return
#     result = InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1955, in inline_call
#     return cls.inline_call_(parent, func, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 2011, in inline_call_
#     tracer.run()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 619, in run
#     and self.step()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 583, in step
#     getattr(self, inst.opname)(inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 349, in wrapper
#     return inner_fn(self, inst)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 1014, in CALL_FUNCTION
#     self.call_function(fn, args, {})
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 517, in call_function
#     self.push(fn.call_function(self, args, kwargs))
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/user_defined.py", line 266, in call_function
#     return super().call_function(tx, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/variables/base.py", line 230, in call_function
#     unimplemented(f"call_function {self} {args} {kwargs}")
#   File "/opt/conda/lib/python3.10/site-packages/torch/_dynamo/exc.py", line 71, in unimplemented
#     raise Unsupported(msg)
# torch._dynamo.exc.Unsupported: call_function UserDefinedObjectVariable(_lru_cache_wrapper) [] {}
# [2023-03-08 21:28:24,457] torch._dynamo.output_graph: [DEBUG] restore_graphstate: removed 0 nodes
# [2023-03-08 21:28:24,457] torch._dynamo.output_graph: [DEBUG] COMPILING GRAPH due to GraphCompileReason(reason='call_function UserDefinedObjectVariable(_lru_cache_wrapper) [] {}', user_stack=[<FrameSummary file /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py, line 992 in forward>, <FrameSummary file /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py, line 805 in get_extended_attention_mask>, <FrameSummary file /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py, line 735 in dtype>, <FrameSummary file /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py, line 192 in get_parameter_dtype>])
# [2023-03-08 21:28:24,621] torch._dynamo.convert_frame: [DEBUG] skipping because no torch.* __getattribute__             /opt/conda/lib/python3.10/site-packages/transformers/configuration_utils.py 257
# [2023-03-08 21:28:24,622] torch._dynamo.convert_frame: [DEBUG] skipping because no torch.* use_return_dict             /opt/conda/lib/python3.10/site-packages/transformers/configuration_utils.py 397
# [2023-03-08 21:28:24,625] torch._dynamo.symbolic_convert: [INFO] Step 1: torchdynamo start tracing get_extended_attention_mask
# [2023-03-08 21:28:24,625] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:804
# [2023-03-08 21:28:24,626] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST dtype []
# [2023-03-08 21:28:24,627] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,627] torch._dynamo.symbolic_convert: [DEBUG] TRACE IS_OP 0 [ConstantVariable(NoneType), ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,628] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 14 [ConstantVariable(bool)]
# [2023-03-08 21:28:24,629] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:805
# [2023-03-08 21:28:24,629] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:24,630] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR dtype [NNModuleVariable()]
# [2023-03-08 21:28:24,631] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object dtype at 0x7f999f1ac500, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 730>
#  735           0 LOAD_GLOBAL              0 (get_parameter_dtype)
#               2 LOAD_FAST                0 (self)
#               4 CALL_FUNCTION            1
#               6 RETURN_VALUE
#
#
# [2023-03-08 21:28:24,632] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:735
# [2023-03-08 21:28:24,632] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL get_parameter_dtype []
# [2023-03-08 21:28:24,633] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self [UserFunctionVariable()]
# [2023-03-08 21:28:24,637] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 1 [UserFunctionVariable(), NNModuleVariable()]
# [2023-03-08 21:28:24,638] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object get_parameter_dtype at 0x7f999f16cea0, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 181>
#  185           0 LOAD_CONST               1 (None)
#               2 STORE_FAST               1 (last_dtype)
#
# 186           4 LOAD_FAST                0 (parameter)
#               6 LOAD_METHOD              0 (parameters)
#               8 CALL_METHOD              0
#              10 GET_ITER
#         >>   12 FOR_ITER                52 (to 118)
#              14 STORE_FAST               2 (t)
#
# 187          16 LOAD_FAST                2 (t)
#              18 LOAD_ATTR                1 (dtype)
#              20 STORE_FAST               1 (last_dtype)
#
# 188          22 LOAD_FAST                2 (t)
#              24 LOAD_METHOD              2 (is_floating_point)
#              26 CALL_METHOD              0
#              28 POP_JUMP_IF_FALSE       58 (to 116)
#
# 192          30 LOAD_GLOBAL              3 (is_torch_tpu_available)
#              32 CALL_FUNCTION            0
#              34 POP_JUMP_IF_FALSE       53 (to 106)
#
# 193          36 LOAD_GLOBAL              4 (XLA_USE_BF16)
#              38 LOAD_GLOBAL              5 (ENV_VARS_TRUE_VALUES)
#              40 CONTAINS_OP              0
#              42 POP_JUMP_IF_FALSE       27 (to 54)
#
# 194          44 LOAD_GLOBAL              6 (torch)
#              46 LOAD_ATTR                7 (bfloat16)
#              48 ROT_TWO
#              50 POP_TOP
#              52 RETURN_VALUE
#
# 195     >>   54 LOAD_GLOBAL              8 (XLA_DOWNCAST_BF16)
#              56 LOAD_GLOBAL              5 (ENV_VARS_TRUE_VALUES)
#              58 CONTAINS_OP              0
#              60 POP_JUMP_IF_FALSE       53 (to 106)
#
# 196          62 LOAD_FAST                2 (t)
#              64 LOAD_ATTR                1 (dtype)
#              66 LOAD_GLOBAL              6 (torch)
#              68 LOAD_ATTR                9 (float)
#              70 COMPARE_OP               2 (==)
#              72 POP_JUMP_IF_FALSE       42 (to 84)
#
# 197          74 LOAD_GLOBAL              6 (torch)
#              76 LOAD_ATTR                7 (bfloat16)
#              78 ROT_TWO
#              80 POP_TOP
#              82 RETURN_VALUE
#
# 198     >>   84 LOAD_FAST                2 (t)
#              86 LOAD_ATTR                1 (dtype)
#              88 LOAD_GLOBAL              6 (torch)
#              90 LOAD_ATTR               10 (double)
#              92 COMPARE_OP               2 (==)
#              94 POP_JUMP_IF_FALSE       53 (to 106)
#
# 199          96 LOAD_GLOBAL              6 (torch)
#              98 LOAD_ATTR               11 (float32)
#             100 ROT_TWO
#             102 POP_TOP
#             104 RETURN_VALUE
#
# 200     >>  106 LOAD_FAST                2 (t)
#             108 LOAD_ATTR                1 (dtype)
#             110 ROT_TWO
#             112 POP_TOP
#             114 RETURN_VALUE
#
# 188     >>  116 JUMP_ABSOLUTE            6 (to 12)
#
# 202     >>  118 LOAD_FAST                1 (last_dtype)
#             120 LOAD_CONST               1 (None)
#             122 IS_OP                    1
#             124 POP_JUMP_IF_FALSE       65 (to 130)
#
# 204         126 LOAD_FAST                1 (last_dtype)
#             128 RETURN_VALUE
#
# 208     >>  130 LOAD_CONST               2 ('module')
#             132 LOAD_GLOBAL             12 (nn)
#             134 LOAD_ATTR               13 (Module)
#             136 LOAD_CONST               3 ('return')
#             138 LOAD_GLOBAL             14 (List)
#             140 LOAD_GLOBAL             15 (Tuple)
#             142 LOAD_GLOBAL             16 (str)
#             144 LOAD_GLOBAL             17 (Tensor)
#             146 BUILD_TUPLE              2
#             148 BINARY_SUBSCR
#             150 BINARY_SUBSCR
#             152 BUILD_TUPLE              4
#             154 LOAD_CONST               4 (<code object find_tensor_attributes at 0x7f999f16cdf0, file "/opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py", line 208>)
#             156 LOAD_CONST               5 ('get_parameter_dtype.<locals>.find_tensor_attributes')
#             158 MAKE_FUNCTION            4 (annotations)
#             160 STORE_FAST               3 (find_tensor_attributes)
#
# 212         162 LOAD_FAST                0 (parameter)
#             164 LOAD_ATTR               18 (_named_members)
#             166 LOAD_FAST                3 (find_tensor_attributes)
#             168 LOAD_CONST               6 (('get_members_fn',))
#             170 CALL_FUNCTION_KW         1
#             172 STORE_FAST               4 (gen)
#
# 213         174 LOAD_CONST               1 (None)
#             176 STORE_FAST               5 (last_tuple)
#
# 214         178 LOAD_FAST                4 (gen)
#             180 GET_ITER
#         >>  182 FOR_ITER                17 (to 218)
#             184 STORE_FAST               6 (tuple)
#
# 215         186 LOAD_FAST                6 (tuple)
#             188 STORE_FAST               5 (last_tuple)
#
# 216         190 LOAD_FAST                6 (tuple)
#             192 LOAD_CONST               7 (1)
#             194 BINARY_SUBSCR
#             196 LOAD_METHOD              2 (is_floating_point)
#             198 CALL_METHOD              0
#             200 POP_JUMP_IF_FALSE      108 (to 216)
#
# 217         202 LOAD_FAST                6 (tuple)
#             204 LOAD_CONST               7 (1)
#             206 BINARY_SUBSCR
#             208 LOAD_ATTR                1 (dtype)
#             210 ROT_TWO
#             212 POP_TOP
#             214 RETURN_VALUE
#
# 216     >>  216 JUMP_ABSOLUTE           91 (to 182)
#
# 220     >>  218 LOAD_FAST                5 (last_tuple)
#             220 LOAD_CONST               7 (1)
#             222 BINARY_SUBSCR
#             224 LOAD_ATTR                1 (dtype)
#             226 RETURN_VALUE
#
#
# [2023-03-08 21:28:24,640] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:185
# [2023-03-08 21:28:24,640] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None []
# [2023-03-08 21:28:24,641] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST last_dtype [ConstantVariable(NoneType)]
# [2023-03-08 21:28:24,642] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:186
# [2023-03-08 21:28:24,643] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST parameter []
# [2023-03-08 21:28:24,643] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR parameters [NNModuleVariable()]
# [2023-03-08 21:28:24,644] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 0 [UserMethodVariable(<function Module.parameters at 0x7f99a56bdf30>, NNModuleVariable())]
# [2023-03-08 21:28:24,843] torch._dynamo.symbolic_convert: [DEBUG] TRACE GET_ITER None [ListIteratorVariable()]
# [2023-03-08 21:28:24,848] torch._dynamo.symbolic_convert: [DEBUG] TRACE FOR_ITER 118 [ListIteratorVariable()]
# [2023-03-08 21:28:24,848] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST t [ListIteratorVariable(), TensorVariable()]
# [2023-03-08 21:28:24,849] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:187
# [2023-03-08 21:28:24,850] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST t [ListIteratorVariable()]
# [2023-03-08 21:28:24,851] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR dtype [ListIteratorVariable(), TensorVariable()]
# ...
# [2023-03-08 21:28:30,482] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:436
# [2023-03-08 21:28:30,483] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST outputs []
# [2023-03-08 21:28:30,483] torch._dynamo.symbolic_convert: [DEBUG] TRACE RETURN_VALUE None [TupleVariable()]
# [2023-03-08 21:28:30,484] torch._dynamo.symbolic_convert: [DEBUG] DONE INLINING <code object forward at 0x7f999f1398f0, file "/opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py", line 415>
# [2023-03-08 21:28:30,484] torch._dynamo.symbolic_convert: [DEBUG] TRACE RETURN_VALUE None [TupleVariable()]
# [2023-03-08 21:28:30,485] torch._dynamo.symbolic_convert: [DEBUG] DONE INLINING <code object _call_impl at 0x7f99a56a9840, file "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1526>
# [2023-03-08 21:28:30,490] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST self_attention_outputs [TupleVariable()]
# [2023-03-08 21:28:30,490] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:502
# [2023-03-08 21:28:30,491] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self_attention_outputs []
# [2023-03-08 21:28:30,491] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST 0 [TupleVariable()]
# [2023-03-08 21:28:30,492] torch._dynamo.symbolic_convert: [DEBUG] TRACE BINARY_SUBSCR None [TupleVariable(), ConstantVariable(int)]
# [2023-03-08 21:28:30,493] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST attention_output [TensorVariable()]
# [2023-03-08 21:28:30,493] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:505
# [2023-03-08 21:28:30,494] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:30,494] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR is_decoder [NNModuleVariable()]
# [2023-03-08 21:28:30,495] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 80 [ConstantVariable(bool)]
# [2023-03-08 21:28:30,496] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:509
# [2023-03-08 21:28:30,496] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self_attention_outputs []
# [2023-03-08 21:28:30,497] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST 1 [TupleVariable()]
# [2023-03-08 21:28:30,497] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None [TupleVariable(), ConstantVariable(int)]
# [2023-03-08 21:28:30,498] torch._dynamo.symbolic_convert: [DEBUG] TRACE BUILD_SLICE 2 [TupleVariable(), ConstantVariable(int), ConstantVariable(NoneType)]
# [2023-03-08 21:28:30,501] torch._dynamo.symbolic_convert: [DEBUG] TRACE BINARY_SUBSCR None [TupleVariable(), SliceVariable()]
# [2023-03-08 21:28:30,502] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST outputs [TupleVariable()]
# [2023-03-08 21:28:30,503] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:511
# [2023-03-08 21:28:30,504] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST None []
# [2023-03-08 21:28:30,504] torch._dynamo.symbolic_convert: [DEBUG] TRACE STORE_FAST cross_attn_present_key_value [ConstantVariable(NoneType)]
# [2023-03-08 21:28:30,505] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:512
# [2023-03-08 21:28:30,506] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self []
# [2023-03-08 21:28:30,506] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR is_decoder [NNModuleVariable()]
# [2023-03-08 21:28:30,507] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_FALSE 222 [ConstantVariable(bool)]
# [2023-03-08 21:28:30,508] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:537
# [2023-03-08 21:28:30,508] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL apply_chunking_to_forward []
# [2023-03-08 21:28:30,509] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:538
# [2023-03-08 21:28:30,510] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self [UserFunctionVariable()]
# [2023-03-08 21:28:30,512] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR feed_forward_chunk [UserFunctionVariable(), NNModuleVariable()]
# [2023-03-08 21:28:30,513] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable())]
# [2023-03-08 21:28:30,513] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR chunk_size_feed_forward [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable()), NNModuleVariable()]
# [2023-03-08 21:28:30,515] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST self [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable()), ConstantVariable(int)]
# [2023-03-08 21:28:30,516] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR seq_len_dim [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable()), ConstantVariable(int), NNModuleVariable()]
# [2023-03-08 21:28:30,517] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST attention_output [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable()), ConstantVariable(int), ConstantVariable(int)]
# [2023-03-08 21:28:30,517] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:537
# [2023-03-08 21:28:30,519] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 4 [UserFunctionVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable()), ConstantVariable(int), ConstantVariable(int), TensorVariable()]
# [2023-03-08 21:28:30,520] torch._dynamo.symbolic_convert: [DEBUG] INLINING <code object apply_chunking_to_forward at 0x7f999efd2600, file "/opt/conda/lib/python3.10/site-packages/transformers/pytorch_utils.py", line 177>
#  215           0 LOAD_GLOBAL              0 (len)
#               2 LOAD_FAST                3 (input_tensors)
#               4 CALL_FUNCTION            1
#               6 LOAD_CONST               1 (0)
#               8 COMPARE_OP               4 (>)
#              10 POP_JUMP_IF_TRUE        13 (to 26)
#              12 LOAD_ASSERTION_ERROR
#              14 LOAD_FAST                3 (input_tensors)
#              16 FORMAT_VALUE             0
#              18 LOAD_CONST               2 (' has to be a tuple/list of tensors')
#              20 BUILD_STRING             2
#              22 CALL_FUNCTION            1
#              24 RAISE_VARARGS            1
#
# 218     >>   26 LOAD_GLOBAL              0 (len)
#              28 LOAD_GLOBAL              1 (inspect)
#              30 LOAD_METHOD              2 (signature)
#              32 LOAD_DEREF               1 (forward_fn)
#              34 CALL_METHOD              1
#              36 LOAD_ATTR                3 (parameters)
#              38 CALL_FUNCTION            1
#              40 STORE_FAST               4 (num_args_in_forward_chunk_fn)
#
# 219          42 LOAD_FAST                4 (num_args_in_forward_chunk_fn)
#              44 LOAD_GLOBAL              0 (len)
#              46 LOAD_FAST                3 (input_tensors)
#              48 CALL_FUNCTION            1
#              50 COMPARE_OP               3 (!=)
#              52 POP_JUMP_IF_FALSE       40 (to 80)
#
# 220          54 LOAD_GLOBAL              4 (ValueError)
#
# 221          56 LOAD_CONST               3 ('forward_chunk_fn expects ')
#              58 LOAD_FAST                4 (num_args_in_forward_chunk_fn)
#              60 FORMAT_VALUE             0
#              62 LOAD_CONST               4 (' arguments, but only ')
#              64 LOAD_GLOBAL              0 (len)
#              66 LOAD_FAST                3 (input_tensors)
#              68 CALL_FUNCTION            1
#              70 FORMAT_VALUE             0
#              72 LOAD_CONST               5 (' input tensors are given')
#              74 BUILD_STRING             5
#
# 220          76 CALL_FUNCTION            1
#              78 RAISE_VARARGS            1
#
# 225     >>   80 LOAD_FAST                1 (chunk_size)
#              82 LOAD_CONST               1 (0)
#              84 COMPARE_OP               4 (>)
#              86 POP_JUMP_IF_FALSE      143 (to 286)
#
# 226          88 LOAD_FAST                3 (input_tensors)
#              90 LOAD_CONST               1 (0)
#              92 BINARY_SUBSCR
#              94 LOAD_ATTR                5 (shape)
#              96 LOAD_DEREF               0 (chunk_dim)
#              98 BINARY_SUBSCR
#             100 STORE_FAST               5 (tensor_shape)
#
# 227         102 LOAD_FAST                3 (input_tensors)
#             104 GET_ITER
#         >>  106 FOR_ITER                22 (to 152)
#             108 STORE_FAST               6 (input_tensor)
#
# 228         110 LOAD_FAST                6 (input_tensor)
#             112 LOAD_ATTR                5 (shape)
#             114 LOAD_DEREF               0 (chunk_dim)
#             116 BINARY_SUBSCR
#             118 LOAD_FAST                5 (tensor_shape)
#             120 COMPARE_OP               3 (!=)
#             122 POP_JUMP_IF_FALSE       75 (to 150)
#
# 229         124 LOAD_GLOBAL              4 (ValueError)
#
# 230         126 LOAD_CONST               6 ('All input tenors have to be of the same shape: ')
#             128 LOAD_FAST                5 (tensor_shape)
#             130 FORMAT_VALUE             0
#             132 LOAD_CONST               7 (', found shape ')
#
# 231         134 LOAD_FAST                6 (input_tensor)
#             136 LOAD_ATTR                5 (shape)
#             138 LOAD_DEREF               0 (chunk_dim)
#             140 BINARY_SUBSCR
#
# 230         142 FORMAT_VALUE             0
#             144 BUILD_STRING             4
#
# 229         146 CALL_FUNCTION            1
#             148 RAISE_VARARGS            1
#
# 228     >>  150 JUMP_ABSOLUTE           53 (to 106)
#
# 234     >>  152 LOAD_FAST                3 (input_tensors)
#             154 LOAD_CONST               1 (0)
#             156 BINARY_SUBSCR
#             158 LOAD_ATTR                5 (shape)
#             160 LOAD_DEREF               0 (chunk_dim)
#             162 BINARY_SUBSCR
#             164 LOAD_FAST                1 (chunk_size)
#             166 BINARY_MODULO
#             168 LOAD_CONST               1 (0)
#             170 COMPARE_OP               3 (!=)
#             172 POP_JUMP_IF_FALSE      102 (to 204)
#
# 235         174 LOAD_GLOBAL              4 (ValueError)
#
# 236         176 LOAD_CONST               8 ('The dimension to be chunked ')
#             178 LOAD_FAST                3 (input_tensors)
#             180 LOAD_CONST               1 (0)
#             182 BINARY_SUBSCR
#             184 LOAD_ATTR                5 (shape)
#             186 LOAD_DEREF               0 (chunk_dim)
#             188 BINARY_SUBSCR
#             190 FORMAT_VALUE             0
#             192 LOAD_CONST               9 (' has to be a multiple of the chunk size ')
#
# 237         194 LOAD_FAST                1 (chunk_size)
#
# 236         196 FORMAT_VALUE             0
#             198 BUILD_STRING             4
#
# 235         200 CALL_FUNCTION            1
#             202 RAISE_VARARGS            1
#
# 240     >>  204 LOAD_FAST                3 (input_tensors)
#             206 LOAD_CONST               1 (0)
#             208 BINARY_SUBSCR
#             210 LOAD_ATTR                5 (shape)
#             212 LOAD_DEREF               0 (chunk_dim)
#             214 BINARY_SUBSCR
#             216 LOAD_FAST                1 (chunk_size)
#             218 BINARY_FLOOR_DIVIDE
#             220 STORE_DEREF              2 (num_chunks)
#
# 243         222 LOAD_GLOBAL              6 (tuple)
#             224 LOAD_CLOSURE             0 (chunk_dim)
#             226 LOAD_CLOSURE             2 (num_chunks)
#             228 BUILD_TUPLE              2
#             230 LOAD_CONST              10 (<code object <genexpr> at 0x7f999efd24a0, file "/opt/conda/lib/python3.10/site-packages/transformers/pytorch_utils.py", line 243>)
#             232 LOAD_CONST              11 ('apply_chunking_to_forward.<locals>.<genexpr>')
#             234 MAKE_FUNCTION            8 (closure)
#             236 LOAD_FAST                3 (input_tensors)
#             238 GET_ITER
#             240 CALL_FUNCTION            1
#             242 CALL_FUNCTION            1
#             244 STORE_FAST               7 (input_tensors_chunks)
#
# 245         246 LOAD_GLOBAL              6 (tuple)
#             248 LOAD_CLOSURE             1 (forward_fn)
#             250 BUILD_TUPLE              1
#             252 LOAD_CONST              12 (<code object <genexpr> at 0x7f999efd2550, file "/opt/conda/lib/python3.10/site-packages/transformers/pytorch_utils.py", line 245>)
#             254 LOAD_CONST              11 ('apply_chunking_to_forward.<locals>.<genexpr>')
#             256 MAKE_FUNCTION            8 (closure)
#             258 LOAD_GLOBAL              7 (zip)
#             260 LOAD_FAST                7 (input_tensors_chunks)
#             262 CALL_FUNCTION_EX         0
#             264 GET_ITER
#             266 CALL_FUNCTION            1
#             268 CALL_FUNCTION            1
#             270 STORE_FAST               8 (output_chunks)
#
# 247         272 LOAD_GLOBAL              8 (torch)
#             274 LOAD_ATTR                9 (cat)
#             276 LOAD_FAST                8 (output_chunks)
#             278 LOAD_DEREF               0 (chunk_dim)
#             280 LOAD_CONST              13 (('dim',))
#             282 CALL_FUNCTION_KW         2
#             284 RETURN_VALUE
#
# 249     >>  286 LOAD_DEREF               1 (forward_fn)
#             288 LOAD_FAST                3 (input_tensors)
#             290 CALL_FUNCTION_EX         0
#             292 RETURN_VALUE
#
#
# [2023-03-08 21:28:30,522] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/pytorch_utils.py:215
# [2023-03-08 21:28:30,522] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL len []
# [2023-03-08 21:28:30,523] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_FAST input_tensors [BuiltinVariable(len)]
# [2023-03-08 21:28:30,524] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 1 [BuiltinVariable(len), TupleVariable()]
# [2023-03-08 21:28:30,525] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_CONST 0 [ConstantVariable(int)]
# [2023-03-08 21:28:30,525] torch._dynamo.symbolic_convert: [DEBUG] TRACE COMPARE_OP > [ConstantVariable(int), ConstantVariable(int)]
# [2023-03-08 21:28:30,528] torch._dynamo.symbolic_convert: [DEBUG] TRACE POP_JUMP_IF_TRUE 26 [ConstantVariable(bool)]
# [2023-03-08 21:28:30,528] torch._dynamo.symbolic_convert: [DEBUG] TRACE starts_line /opt/conda/lib/python3.10/site-packages/transformers/pytorch_utils.py:218
# [2023-03-08 21:28:30,529] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL len []
# [2023-03-08 21:28:30,529] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_GLOBAL inspect [BuiltinVariable(len)]
# [2023-03-08 21:28:30,530] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_ATTR signature [BuiltinVariable(len), PythonModuleVariable()]
# [2023-03-08 21:28:30,531] torch._dynamo.symbolic_convert: [DEBUG] TRACE LOAD_DEREF forward_fn [BuiltinVariable(len), LambdaVariable()]
# [2023-03-08 21:28:30,532] torch._dynamo.symbolic_convert: [DEBUG] TRACE CALL_FUNCTION 1 [BuiltinVariable(len), LambdaVariable(), UserMethodVariable(<function BertLayer.feed_forward_chunk at 0x7f999e6a2dd0>, NNModuleVariable())]
